# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import cv2 as cv2

# %%
path_to_data = '/kaggle/input/mango-leaf-disease-detection-raw-augmented-data'

# %%
data = []
labels = []

img_size = (224, 224)
for folder in os.listdir(path_to_data):
    print(folder)
    for file in os.listdir(os.path.join(path_to_data, folder)):
        img_path = os.path.join(path_to_data, folder, file)
        img = cv2.imread(img_path, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, img_size)
        data.append(img)
        labels.append(folder)

# Convert to NumPy arrays if needed
data = np.array(data, dtype=np.float32)
labels = np.array(labels)
# Out:
# gall_midge
# anthracnose
# die_black
# powdery_mildew
# healthy

# %%
# Normalization
data = data/255.0

# %%
data[0]
# Out:
# array([[[0.6039216 , 0.59607846, 0.57254905],
#         [0.60784316, 0.6       , 0.5764706 ],
#         [0.60784316, 0.6       , 0.5764706 ],
#         ...,
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.63529414, 0.61960787, 0.61960787],
#         [0.6313726 , 0.61960787, 0.6117647 ]],
#
#        [[0.6039216 , 0.59607846, 0.57254905],
#         [0.60784316, 0.6       , 0.5764706 ],
#         [0.60784316, 0.6       , 0.5764706 ],
#         ...,
#         [0.6392157 , 0.627451  , 0.62352943],
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.63529414, 0.61960787, 0.61960787]],
#
#        [[0.6039216 , 0.59607846, 0.57254905],
#         [0.60784316, 0.6       , 0.5764706 ],
#         [0.60784316, 0.6       , 0.5764706 ],
#         ...,
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.6392157 , 0.62352943, 0.61960787]],
#
#        ...,
#
#        [[0.7137255 , 0.69803923, 0.68235296],
#         [0.7137255 , 0.69803923, 0.68235296],
#         [0.7176471 , 0.7019608 , 0.6862745 ],
#         ...,
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8039216 , 0.7882353 , 0.78039217],
#         [0.80784315, 0.7882353 , 0.78039217]],
#
#        [[0.7137255 , 0.69803923, 0.68235296],
#         [0.7137255 , 0.69803923, 0.68235296],
#         [0.7176471 , 0.7019608 , 0.6862745 ],
#         ...,
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.80784315, 0.7921569 , 0.78039217]],
#
#        [[0.7137255 , 0.69411767, 0.68235296],
#         [0.7137255 , 0.69803923, 0.68235296],
#         [0.7176471 , 0.7019608 , 0.6862745 ],
#         ...,
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8117647 , 0.7921569 , 0.78431374]]], dtype=float32)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform labels
encoded_labels = label_encoder.fit_transform(labels)

# Create mapping of original labels to encoded values
label_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))

# Print the mapping
print("Label Mapping:")
for original, encoded in label_mapping.items():
    print(f"{original} -> {encoded}")

# Print the transformed labels
print("\nEncoded Labels:")
print(encoded_labels)
# Out:
# Label Mapping:
# anthracnose -> 0
# die_black -> 1
# gall_midge -> 2
# healthy -> 3
# powdery_mildew -> 4
#
# Encoded Labels:
# [2 2 2 ... 3 3 3]

# %%
np.unique(encoded_labels)
# Out:
# array([0, 1, 2, 3, 4])

# %%
data[0]
# Out:
# array([[[0.6039216 , 0.59607846, 0.57254905],
#         [0.60784316, 0.6       , 0.5764706 ],
#         [0.60784316, 0.6       , 0.5764706 ],
#         ...,
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.63529414, 0.61960787, 0.61960787],
#         [0.6313726 , 0.61960787, 0.6117647 ]],
#
#        [[0.6039216 , 0.59607846, 0.57254905],
#         [0.60784316, 0.6       , 0.5764706 ],
#         [0.60784316, 0.6       , 0.5764706 ],
#         ...,
#         [0.6392157 , 0.627451  , 0.62352943],
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.63529414, 0.61960787, 0.61960787]],
#
#        [[0.6039216 , 0.59607846, 0.57254905],
#         [0.60784316, 0.6       , 0.5764706 ],
#         [0.60784316, 0.6       , 0.5764706 ],
#         ...,
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.6392157 , 0.62352943, 0.61960787],
#         [0.6392157 , 0.62352943, 0.61960787]],
#
#        ...,
#
#        [[0.7137255 , 0.69803923, 0.68235296],
#         [0.7137255 , 0.69803923, 0.68235296],
#         [0.7176471 , 0.7019608 , 0.6862745 ],
#         ...,
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8039216 , 0.7882353 , 0.78039217],
#         [0.80784315, 0.7882353 , 0.78039217]],
#
#        [[0.7137255 , 0.69803923, 0.68235296],
#         [0.7137255 , 0.69803923, 0.68235296],
#         [0.7176471 , 0.7019608 , 0.6862745 ],
#         ...,
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.80784315, 0.7921569 , 0.78039217]],
#
#        [[0.7137255 , 0.69411767, 0.68235296],
#         [0.7137255 , 0.69803923, 0.68235296],
#         [0.7176471 , 0.7019608 , 0.6862745 ],
#         ...,
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8039216 , 0.7921569 , 0.78431374],
#         [0.8117647 , 0.7921569 , 0.78431374]]], dtype=float32)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# Define label mapping
label_mapping = {
    0: "Anthracnose",
    1: "Die Black",
    2: "Gall Midge",
    3: "Healthy",
    4: "Powdery Mildew"
}

# Sample 5 random indices from each class
r_b = random.sample(list(np.where(encoded_labels == 0)[0]), 5)
r_f = random.sample(list(np.where(encoded_labels == 1)[0]), 5)
r_g = random.sample(list(np.where(encoded_labels == 2)[0]), 5)
r_m = random.sample(list(np.where(encoded_labels == 3)[0]), 5)
r_se = random.sample(list(np.where(encoded_labels == 4)[0]), 5)

# Combine the selected indices and reshape into a 5x5 grid
plots = np.array(r_b + r_f + r_g + r_m + r_se).reshape(5, 5)

# Create subplots
fig, ax = plt.subplots(5, 5, figsize=(10, 10))
fig.subplots_adjust(hspace=0.5, wspace=0.5)  # Adjust spacing

# Plot images with corresponding class names
for i in range(5):
    for j in range(5):
        idx = plots[i, j]
        ax[i, j].imshow(data[idx])  # RGB images, so no cmap='gray'
        ax[i, j].set_title(f"{label_mapping[encoded_labels[idx]]}", fontsize=8)
        ax[i, j].axis('off')

plt.show()

# %%
# Flatten each color channel
red_values = data[:, :, :, 0].ravel()   # Red channel
green_values = data[:, :, :, 1].ravel() # Green channel
blue_values = data[:, :, :, 2].ravel()  # Blue channel

# Plot histograms
plt.figure(figsize=(12, 6))
plt.hist(red_values, bins=256, color='red', alpha=0.6, label="Red Channel")
plt.hist(green_values, bins=256, color='green', alpha=0.6, label="Green Channel")
plt.hist(blue_values, bins=256, color='blue', alpha=0.6, label="Blue Channel")

# Labels and Title
plt.xlabel("Pixel Intensity (0-255)")
plt.ylabel("Frequency")
plt.title("RGB Histogram of All Images")
plt.legend()
plt.show()

# %%
# Count occurrences of each label
unique_labels, label_counts = np.unique(encoded_labels, return_counts=True)

# Create a bar plot
plt.figure(figsize=(8, 5))
ax = sns.barplot(x=unique_labels, y=label_counts, palette="viridis")

# Add count labels on top of each bar
for i, count in enumerate(label_counts):
    ax.text(i, count + 0.5, str(count), ha='center', fontsize=12, fontweight='bold')

# Labels and title
plt.xlabel("Labels")
plt.ylabel("Count")
plt.title("Distribution of Encoded Labels")
plt.show()

# %%
from sklearn.model_selection import train_test_split
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(data, encoded_labels, test_size=0.2, random_state=42, shuffle=True)

# Ensure correct shape for RGB images
X_train = X_train.reshape(-1, 224, 224, 3)
X_test = X_test.reshape(-1, 224, 224, 3)

# Define number of classes
num_classes = len(np.unique(encoded_labels))

print("Number of classes:", num_classes)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# Number of classes: 5
# X_train shape: (6984, 224, 224, 3)
# X_test shape: (1746, 224, 224, 3)

# %%
print("Unique classes in y_train:", np.unique(y_train))
print("Unique classes in y_test:", np.unique(y_test))
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# Unique classes in y_train: [0 1 2 3 4]
# Unique classes in y_test: [0 1 2 3 4]
# y_train shape: (6984,)
# y_test shape: (1746,)

# %% [markdown]
# # AlexNet

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, AveragePooling2D, Add, Flatten, Dense,ZeroPadding2D
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
import tensorflow as tf

# %%
input_shape = (224, 224, 3)  # Input shape for grayscale images

model5 = tf.keras.Sequential([
        # 1st Convolutional Layer
        tf.keras.layers.Resizing(227,227, interpolation="bilinear", input_shape = data.shape[1:]),
        tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227, 227, 3)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)),

        # 2nd Convolutional Layer
        tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)),

        # 3rd Convolutional Layer
        tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),

        # 4th Convolutional Layer
        tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),

        # 5th Convolutional Layer
        tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2)),

        # Flattening
        tf.keras.layers.Flatten(),

        # 1st Fully Connected Layer
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),

        # 2nd Fully Connected Layer
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),

        # 3rd Fully Connected Layer
        tf.keras.layers.Dense(5, activation='softmax')
    ])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model5.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define the path where the model with the best parameters will be saved
checkpoint_path = "best_model.keras"

# Create a callback that saves the model with the best validation accuracy
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_accuracy',  # Monitor validation accuracy
    save_best_only=True,
    save_weights_only=False,
    mode='max',  # Save when val_accuracy is maximized
    verbose=1
)

# Create an EarlyStopping callback with patience=5
early_stopping_callback = EarlyStopping(
    monitor='val_accuracy',  # Monitor validation accuracy
    patience=10,  # Stop training if no improvement after 10 epochs
    mode='max',  # Check for maximization of val_accuracy
    verbose=1,
    restore_best_weights=True  # Restore model weights from the epoch with the best validation accuracy
)

# Train the model with the checkpoint and early stopping callbacks
history5 = model5.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=50,
                    batch_size=32,
                    callbacks=[checkpoint_callback, early_stopping_callback])
# Out:
# Epoch 1/50
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5438 - loss: 1.7853
# Epoch 1: val_accuracy improved from -inf to 0.43164, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 145ms/step - accuracy: 0.5445 - loss: 1.7818 - val_accuracy: 0.4316 - val_loss: 1.4855
# Epoch 2/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8329 - loss: 0.4994
# Epoch 2: val_accuracy improved from 0.43164 to 0.65211, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.8331 - loss: 0.4989 - val_accuracy: 0.6521 - val_loss: 0.9260
# Epoch 3/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8785 - loss: 0.3406
# Epoch 3: val_accuracy improved from 0.65211 to 0.88618, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - accuracy: 0.8786 - loss: 0.3403 - val_accuracy: 0.8862 - val_loss: 0.3154
# Epoch 4/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9115 - loss: 0.2489
# Epoch 4: val_accuracy did not improve from 0.88618
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.9115 - loss: 0.2487 - val_accuracy: 0.8690 - val_loss: 0.3594
# Epoch 5/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9294 - loss: 0.1999
# Epoch 5: val_accuracy improved from 0.88618 to 0.93629, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.9294 - loss: 0.1997 - val_accuracy: 0.9363 - val_loss: 0.1676
# Epoch 6/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9409 - loss: 0.1696
# Epoch 6: val_accuracy did not improve from 0.93629
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9410 - loss: 0.1694 - val_accuracy: 0.8661 - val_loss: 0.3497
# Epoch 7/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9519 - loss: 0.1449
# Epoch 7: val_accuracy improved from 0.93629 to 0.96349, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.9518 - loss: 0.1448 - val_accuracy: 0.9635 - val_loss: 0.0949
# Epoch 8/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9625 - loss: 0.1093
# Epoch 8: val_accuracy did not improve from 0.96349
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 0.9625 - loss: 0.1093 - val_accuracy: 0.9384 - val_loss: 0.1849
# Epoch 9/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9653 - loss: 0.1068
# Epoch 9: val_accuracy did not improve from 0.96349
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9654 - loss: 0.1066 - val_accuracy: 0.9621 - val_loss: 0.1226
# Epoch 10/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9755 - loss: 0.0733
# Epoch 10: val_accuracy did not improve from 0.96349
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9755 - loss: 0.0733 - val_accuracy: 0.9449 - val_loss: 0.1475
# Epoch 11/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9725 - loss: 0.0781
# Epoch 11: val_accuracy improved from 0.96349 to 0.96779, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.9725 - loss: 0.0780 - val_accuracy: 0.9678 - val_loss: 0.0829
# Epoch 12/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9784 - loss: 0.0698
# Epoch 12: val_accuracy improved from 0.96779 to 0.97566, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - accuracy: 0.9784 - loss: 0.0697 - val_accuracy: 0.9757 - val_loss: 0.0625
# Epoch 13/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9866 - loss: 0.0401
# Epoch 13: val_accuracy did not improve from 0.97566
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9865 - loss: 0.0402 - val_accuracy: 0.9535 - val_loss: 0.1226
# Epoch 14/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9801 - loss: 0.0542
# Epoch 14: val_accuracy did not improve from 0.97566
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9802 - loss: 0.0541 - val_accuracy: 0.9628 - val_loss: 0.0930
# Epoch 15/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9849 - loss: 0.0425
# Epoch 15: val_accuracy did not improve from 0.97566
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9849 - loss: 0.0425 - val_accuracy: 0.8926 - val_loss: 0.3029
# Epoch 16/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9848 - loss: 0.0444
# Epoch 16: val_accuracy improved from 0.97566 to 0.98282, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - accuracy: 0.9848 - loss: 0.0444 - val_accuracy: 0.9828 - val_loss: 0.0524
# Epoch 17/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9893 - loss: 0.0344
# Epoch 17: val_accuracy did not improve from 0.98282
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9892 - loss: 0.0344 - val_accuracy: 0.9699 - val_loss: 0.1041
# Epoch 18/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9916 - loss: 0.0305
# Epoch 18: val_accuracy did not improve from 0.98282
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9915 - loss: 0.0306 - val_accuracy: 0.7416 - val_loss: 1.1459
# Epoch 19/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9881 - loss: 0.0321
# Epoch 19: val_accuracy improved from 0.98282 to 0.98425, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.9880 - loss: 0.0321 - val_accuracy: 0.9843 - val_loss: 0.0505
# Epoch 20/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9890 - loss: 0.0344
# Epoch 20: val_accuracy improved from 0.98425 to 0.98926, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.9891 - loss: 0.0344 - val_accuracy: 0.9893 - val_loss: 0.0320
# Epoch 21/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9948 - loss: 0.0186
# Epoch 21: val_accuracy did not improve from 0.98926
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9948 - loss: 0.0186 - val_accuracy: 0.9864 - val_loss: 0.0438
# Epoch 22/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9935 - loss: 0.0218
# Epoch 22: val_accuracy improved from 0.98926 to 0.99499, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - accuracy: 0.9935 - loss: 0.0218 - val_accuracy: 0.9950 - val_loss: 0.0218
# Epoch 23/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9949 - loss: 0.0198
# Epoch 23: val_accuracy did not improve from 0.99499
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9949 - loss: 0.0198 - val_accuracy: 0.9936 - val_loss: 0.0144
# Epoch 24/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9947 - loss: 0.0180
# Epoch 24: val_accuracy did not improve from 0.99499
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9947 - loss: 0.0180 - val_accuracy: 0.9234 - val_loss: 0.1977
# Epoch 25/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9929 - loss: 0.0204
# Epoch 25: val_accuracy did not improve from 0.99499
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9929 - loss: 0.0204 - val_accuracy: 0.9878 - val_loss: 0.0397
# Epoch 26/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9947 - loss: 0.0183
# Epoch 26: val_accuracy did not improve from 0.99499
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9947 - loss: 0.0183 - val_accuracy: 0.9914 - val_loss: 0.0319
# Epoch 27/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9964 - loss: 0.0121
# Epoch 27: val_accuracy did not improve from 0.99499
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9963 - loss: 0.0122 - val_accuracy: 0.9771 - val_loss: 0.0577
# Epoch 28/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9970 - loss: 0.0156
# Epoch 28: val_accuracy did not improve from 0.99499
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9970 - loss: 0.0156 - val_accuracy: 0.9055 - val_loss: 0.2795
# Epoch 29/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9968 - loss: 0.0111
# Epoch 29: val_accuracy did not improve from 0.99499
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9968 - loss: 0.0111 - val_accuracy: 0.9936 - val_loss: 0.0254
# Epoch 30/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9968 - loss: 0.0128
# Epoch 30: val_accuracy improved from 0.99499 to 0.99571, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.9967 - loss: 0.0128 - val_accuracy: 0.9957 - val_loss: 0.0134
# Epoch 31/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9965 - loss: 0.0138
# Epoch 31: val_accuracy did not improve from 0.99571
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9964 - loss: 0.0138 - val_accuracy: 0.8218 - val_loss: 0.5124
# Epoch 32/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9967 - loss: 0.0163
# Epoch 32: val_accuracy did not improve from 0.99571
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9967 - loss: 0.0162 - val_accuracy: 0.9957 - val_loss: 0.0103
# Epoch 33/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9953 - loss: 0.0131
# Epoch 33: val_accuracy did not improve from 0.99571
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9953 - loss: 0.0132 - val_accuracy: 0.9914 - val_loss: 0.0329
# Epoch 34/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9951 - loss: 0.0190
# Epoch 34: val_accuracy did not improve from 0.99571
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9951 - loss: 0.0189 - val_accuracy: 0.9936 - val_loss: 0.0188
# Epoch 35/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9978 - loss: 0.0094
# Epoch 35: val_accuracy did not improve from 0.99571
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9978 - loss: 0.0094 - val_accuracy: 0.9957 - val_loss: 0.0114
# Epoch 36/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9965 - loss: 0.0102
# Epoch 36: val_accuracy improved from 0.99571 to 0.99642, saving model to best_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - accuracy: 0.9965 - loss: 0.0101 - val_accuracy: 0.9964 - val_loss: 0.0139
# Epoch 37/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9977 - loss: 0.0087
# Epoch 37: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9976 - loss: 0.0087 - val_accuracy: 0.8848 - val_loss: 0.3651
# Epoch 38/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9937 - loss: 0.0142
# Epoch 38: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9938 - loss: 0.0142 - val_accuracy: 0.9936 - val_loss: 0.0208
# Epoch 39/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9983 - loss: 0.0088
# Epoch 39: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9983 - loss: 0.0088 - val_accuracy: 0.9757 - val_loss: 0.0825
# Epoch 40/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9964 - loss: 0.0107
# Epoch 40: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9964 - loss: 0.0107 - val_accuracy: 0.9964 - val_loss: 0.0115
# Epoch 41/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9963 - loss: 0.0113
# Epoch 41: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.9964 - val_loss: 0.0079
# Epoch 42/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9975 - loss: 0.0100
# Epoch 42: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9975 - loss: 0.0100 - val_accuracy: 0.9950 - val_loss: 0.0151
# Epoch 43/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9967 - loss: 0.0093
# Epoch 43: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9967 - loss: 0.0092 - val_accuracy: 0.9964 - val_loss: 0.0114
# Epoch 44/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9978 - loss: 0.0067
# Epoch 44: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9978 - loss: 0.0066 - val_accuracy: 0.9957 - val_loss: 0.0134
# Epoch 45/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9974 - loss: 0.0106
# Epoch 45: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9974 - loss: 0.0107 - val_accuracy: 0.9964 - val_loss: 0.0166
# Epoch 46/50
# 174/175 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9985 - loss: 0.0101
# Epoch 46: val_accuracy did not improve from 0.99642
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.9985 - loss: 0.0101 - val_accuracy: 0.9914 - val_loss: 0.0325
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 36.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Labels
class_labels = ['anthracnose', 'die_black', 'gall_midge', 'healthy', 'powdery_mildew']

# Predict class probabilities
y_pred_probs = model5.predict(X_test)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Ensure y_test is in correct format
if len(y_test.shape) > 1 and y_test.shape[1] > 1:  # If one-hot encoded
    y_true = np.argmax(y_test, axis=1)  # Convert to class labels
else:  
    y_true = y_test  # Already in label format

# Compute accuracy, precision, recall, and F1 score
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Compute Sensitivity and Specificity for Multi-Class
class_sensitivity = np.diag(cm) / np.sum(cm, axis=1)  # Sensitivity per class
class_specificity = np.diag(cm) / np.sum(cm, axis=0)  # Specificity per class
sensitivity = np.mean(class_sensitivity)  # Mean Sensitivity
specificity = np.mean(class_specificity)  # Mean Specificity

# Print Evaluation Metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall (Sensitivity): {sensitivity:.4f}")
print(f"Test Specificity: {specificity:.4f}")
print(f"Test F1 Score: {f1:.4f}")
print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=class_labels))

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step
# Test Accuracy: 0.9937
# Test Precision: 0.9940
# Test Recall (Sensitivity): 0.9937
# Test Specificity: 0.9940
# Test F1 Score: 0.9938
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#    anthracnose       1.00      0.99      1.00       321
#      die_black       1.00      1.00      1.00       434
#     gall_midge       0.99      0.98      0.99       399
#        healthy       0.98      1.00      0.99       338
# powdery_mildew       1.00      0.99      1.00       254
#
#       accuracy                           0.99      1746
#      macro avg       0.99      0.99      0.99      1746
#   weighted avg       0.99      0.99      0.99      1746

# %%
model5.save('/kaggle/working/AlexNet.keras')
